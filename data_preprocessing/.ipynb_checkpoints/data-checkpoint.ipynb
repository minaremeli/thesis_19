# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#        num_of_insertions  num_of_deletions  num_of_changed_files  day_of_week  \
# 0                    140               107                    10            2
# 1                    367               291                     6            4
# 2                     10                 9                     1            4
# 3                     44                 5                     2            1
# 4                     31                13                     2            3
# 5                     92                61                    13            1
# 6                     72                45                     4            1
# 7                     26                12                     2            6
# 8                      3                 2                     2            4
# 9                    366                 2                    10            1
# 10                  1032               253                     8            0
# ...

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df1
# Out:
#        num_of_insertions  num_of_deletions  num_of_changed_files  day_of_week  \
# 124                    5                 5                     3            3
# 806                 5131              1737                    43            1
# 1138                 375                17                    18            1
# 1302                  14              1091                    20            2
# 1422                  37                17                     5            1
# 1492                   3                78                     5            0
# 1494                  84               318                     7            2
# 1821                 537                18                     7            1
# 2503                  66               139                     8            5
# 2554                  50                40                    19            0
# 2778                 379                17                     8            2
# ...

# %%
df1.shape
# Out:
# (56, 9)
