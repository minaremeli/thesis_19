# %%
import pandas as pd

# %%
df = pd.read_csv("../data_preprocessing/data.csv")

# %%
df
# Out:
#        num_of_insertions  num_of_deletions  num_of_changed_files  day_of_week  \
# 0                    140               107                    10            2
# 1                    367               291                     6            5
# 2                     10                 9                     1            4
# 3                     44                 5                     2            1
# 4                     31                13                     2            3
# 5                     92                61                    13            1
# 6                     72                45                     4            1
# 7                     26                12                     2            0
# 8                      3                 2                     2            4
# 9                    366                 2                    10            1
# 10                  1032               253                     8            0
# 11                   226                78                     7            2
# 12                   516              1644                     6            0
# 13                    64                 2                     2            5
# 14                   204                98                    11            2
# 15                    22                13                     6            6
# 16                    13                65                     3            2
# 17                   144                12                     5            1
# 18                    20                 0                     1            4
# 19                  1695              1306                   221            4
# 20                  1286                 0                    15            0
# 21                    57                47                     2            1
# 22                   509               424                    10            3
# 23                   778                11                    25            1
# 24                   248                34                    34            4
# 25                   948               406                    12            1
# 26                   217               268                    41            1
# 27                   309                 3                    17            3
# 28                   118                13                     6            3
# 29                   756               201                    18            2
# ...                  ...               ...                   ...          ...
# 12916                 19                 1                     2            1
# 12917                 17                 3                     4            4
# 12918                 51               900                    14            5
# 12919               4414                 3                    21            0
# 12920                 32                22                     1            0
# 12921                552               134                     8            1
# 12922                  5                 1                     1            3
# 12923                 12                12                     8            3
# 12924                 64                 7                     3            2
# 12925                  0                 1                     1            3
# 12926                975                35                    15            3
# 12927                 39             58696                   268            0
# 12928                176                43                     7            1
# 12929                  4                 4                     1            4
# 12930                  7                 5                     2            5
# 12931                 13                 1                     1            4
# 12932                  7                10                     5            4
# 12933                 45                 9                    19            2
# 12934                  4                 2                     1            1
# 12935                228               231                     2            3
# 12936                228                12                     9            1
# 12937                  2                16                     1            0
# 12938                 82                 2                     5            3
# 12939                 53                29                     4            1
# 12940                  0                29                     1            3
# 12941                  0              1231                     1            4
# 12942                 53                 4                     3            4
# 12943                 45                 8                     2            0
# 12944                  8                 2                     1            3
# 12945                 10                 0                     1            4
#
#        hour_of_commit  solve_time  resolution_time  solve_res_diff  \
# 0                   4  39213448.0       39213482.0            34.0
# 1                   1   2078793.0        2078920.0           127.0
# 2                   3     11618.0          11673.0            55.0
# 3                   0    363535.0         363895.0           360.0
# 4                  14   1446670.0        1475574.0         28904.0
# 5                   5   2858508.0        2858529.0            21.0
# 6                  21   1316894.0        1316933.0            39.0
# 7                   1   2007361.0        2007411.0            50.0
# 8                   8   2587851.0        2589166.0          1315.0
# 9                   8  12624119.0       12624159.0            40.0
# 10                 23    333741.0         333837.0            96.0
# 11                 23    516491.0         516553.0            62.0
# 12                 22    432239.0         432268.0            29.0
# 13                 23    349724.0         351627.0          1903.0
# 14                  4   1056508.0        1056530.0            22.0
# 15                  5    123981.0         124177.0           196.0
# 16                  5    367298.0         367317.0            19.0
# 17                 15    514095.0         514842.0           747.0
# 18                 13      5662.0           5703.0            41.0
# 19                 20   1373997.0        1723322.0        349325.0
# 20                 22   3883963.0        3884073.0           110.0
# 21                 22    343824.0         343858.0            34.0
# 22                 21     95283.0          97565.0          2282.0
# 23                 22   3025024.0        3025392.0           368.0
# 24                 16   5530073.0        5530251.0           178.0
# 25                 14   2236386.0        2237533.0          1147.0
# 26                 23   1309722.0        1309752.0            30.0
# 27                  6   5106059.0        5106081.0            22.0
# 28                 14   2298770.0        2298923.0           153.0
# 29                 16   2284673.0        2284738.0            65.0
# ...               ...         ...              ...             ...
# 12916              19   1689103.0        1689127.0            24.0
# 12917              17    257903.0         257953.0            50.0
# 12918               2   7287212.0       10806844.0       3519632.0
# 12919              19   2414780.0        2626540.0        211760.0
# 12920              14    265314.0         265378.0            64.0
# 12921               1    446168.0         446199.0            31.0
# 12922               2    191186.0         191211.0            25.0
# 12923              22      3362.0           3379.0            17.0
# 12924              15     95230.0          95497.0           267.0
# 12925              23    160710.0         160804.0            94.0
# 12926              16  36211650.0       36211764.0           114.0
# 12927              15   5068383.0        5068426.0            43.0
# 12928               9    316478.0         317415.0           937.0
# 12929              23   3217088.0        6685037.0       3467949.0
# 12930              19    499859.0         499890.0            31.0
# 12931              19     70577.0          70656.0            79.0
# 12932              17     72986.0          73087.0           101.0
# 12933               9   2856384.0        2856448.0            64.0
# 12934               5    634984.0         635005.0            21.0
# 12935               4  26018549.0       25974853.0         43696.0
# 12936              15   4741582.0        4741695.0           113.0
# 12937               9    657646.0         657719.0            73.0
# 12938              22     67019.0          67049.0            30.0
# 12939               0    432727.0         432788.0            61.0
# 12940              23  11861896.0       11861996.0           100.0
# 12941               9       116.0            147.0            31.0
# 12942              14    165793.0         251034.0         85241.0
# 12943              16   2213887.0        2213907.0            20.0
# 12944              19     77351.0          77731.0           380.0
# 12945               6    184953.0         197670.0         12717.0
#
#        number_of_comments                                            summary  \
# 0                       8  Predicates pushed down to hbase is not handled...
# 1                      15  LlapTaskUmbilicalExternalClient should not sta...
# 2                       3  CBO (Calcite Return Path): Tag not set up corr...
# 3                       5  Bug in ORC Timestamp reader returns wrong nano...
# 4                      13  beeline throws exceptions with parsing hive co...
# 5                      12       Remove deprecated Avro's Schema.parse usages
# 6                       9  Hive Druid indexing not dealing with decimals ...
# 7                       5  HiveResultSetMetaData.getPrecision() fails for...
# 8                      13  WebUI "Show Query" tab prints "UNKNOWN" instea...
# 9                       9              Add GenericUDF to create arrays, maps
# 10                     12                        VectorFileSinkArrowOperator
# 11                     14  Alter rename partition Perm inheritance and ge...
# 12                     10  Vectorization: Add a debug config option to di...
# 13                      5  SELECT statement fails after UPDATE with hive....
# 14                     12  move lock retry logic into ZooKeeperHiveLockMa...
# 15                      5       Rename "Tez File Merge Work" to smaller name
# 16                      3  Adding consistency check at jobClose() when co...
# 17                     11  Hive drop table on encyption zone fails for ex...
# 18                      1  LLAP: Add llap-daemon to the Tez session if th...
# 19                     17  add file type support to file metadata by expr...
# 20                     21        Create a set of builders for Thrift classes
# 21                     12  LLAP: logs urls should use daemon container id...
# 22                      9  Fix Select query Fix Double column serde and s...
# 23                     22     Need new "show" functionality for transactions
# 24                     21  Add table type information to HMS log notifica...
# 25                      6  Multi-insert query drops Filter before file ou...
# 26                     12                 Add ProjectRemove rule on CBO path
# 27                     10                    Implement grouping sets in hive
# 28                     17  Create a separate API for remote Spark Context...
# 29                     19                  DR for function Binaries on HDFS
# ...                   ...                                                ...
# 12916                   5  Point users to hive-users@publists.facebook.co...
# 12917                   3  GetTablesOperation pull all the tables meta ir...
# 12918                  36  Make ORC InputFormat/OutputFormat usable outsi...
# 12919                  25                             Syslog storage handler
# 12920                   6  PostExecOrcFileDump doesn't work with ACID tables
# 12921                  15  Insert overwrite table query has strange behav...
# 12922                   7         Add PerfLogger to log4j2.properties logger
# 12923                   5             Fix broken tests after maven merge (1)
# 12924                   5  Remove double formatting bug followup of HIVE-...
# 12925                   7        fix nonReserved list in IdentifiersParser.g
# 12926                  49                            WebUI query plan graphs
# 12927                  26              Remove deprecated methods in HCatalog
# 12928                   8  Correctness of CASE folding in the presence of...
# 12929                  28  Add more q-tests for Hive-on-Spark with Parque...
# 12930                   9  hive.warehouse.subdir.inherit.perms doesn't wo...
# 12931                   7             LLAP: some Tez INFO logs are too noisy
# 12932                  20       hive-schema-0.13.0.postgres.sql doesn't work
# 12933                  11  Compiler should save the transform URI as inpu...
# 12934                  10  alter table drop partition is acquiring the wr...
# 12935                  26  Change hive.stats.fetch.column.stats value to ...
# 12936                  19  Beeline IncrementalRows should buffer rows and...
# 12937                   8  CBO: Calcite Operator To Hive Operator (Calcit...
# 12938                   6               select expression with optional "as"
# 12939                   5  vectorized logarithm produces results for 0 th...
# 12940                   6  The method humanReadableInt in HiveStringUtils...
# 12941                   4  MetaStoreUtils.java.orig checked in mistakenly...
# 12942                   6    Constant propagation oversimplifies projections
# 12943                   9  ErrorMsg has several messages that reuse the s...
# 12944                   9  BytesBytes hash table - better capacity exhaus...
# 12945                   6  JDBC: JDBC Standalone should not be in the lib...
#
#                                              description  \
# 0      Test result could not show the difference beca...
# 1      Followup task from [~sseth] and [~sershe] afte...
# 2                                                    NaN
# 3      ORC timestamp writer stores the number of trai...
# 4      When beeline has a connection to a server, in ...
# 5      Schema.parse has been deprecated by Avro, howe...
# 6      Currently, a decimal column is indexed as doub...
# 7      Can happen if you have a null in the select cl...
# 8      In the Hive WebUI / Drilldown: the Show Query ...
# 9      Here is an example:\n{code}\nSELECT array(1,2,...
# 10     Bypass the row-mode FileSinkOperator for pushi...
# 11     Found this issue while looking at the method m...
# 12     Debugging scratch column reuse is particularly...
# 13     *Reproducer*\r\n{code:sql}\r\n set hive.optimi...
# 14                                                   NaN
# 15     This is just a cosmetic change. The "Tez File ...
# 16     In case of dynamic partition insert, FileSinkO...
# 17     When dropping an external table with its data ...
# 18     Add llap-daemon-site.xml to the TezConf and se...
# 19     Expr filtering, automatic caching, etc. should...
# 20     Instantiating some of the Thrift classes is pa...
# 21     The containerId used for log url generation is...
# 22     This PR has 2 fixes.\nFirst, fixes the limit o...
# 23     With the addition of transactions and compacti...
# 24     The DB notifications used by HiveMetaStore sho...
# 25     To reproduce:\n\n{noformat}\nCREATE TABLE T_A ...
# 26     When these rules fire we will get shorter and ...
# 27                                                   NaN
# 28     Based on discussions in HIVE-8972, it seems ma...
# 29     # We have to make sure that during incremental...
# ...                                                  ...
# 12916  Now that Hive has an externally available mail...
# 12917  GetTablesOperation pull all the tables meta ir...
# 12918  ORC InputFormat/OutputFormat is currently not ...
# 12919  It will be useful to read syslog generated log...
# 12920                                                NaN
# 12921  Insert overwrite table query has strange behav...
# 12922  To enable perflogging, root logging has to be ...
# 12923  Not surprisingly a couple new tests were in a ...
# 12924  HIVE-19382 has a minor bug that happens when u...
# 12925  some keywords that should have been reserved (...
# 12926  Hi all,\n\nI’m working on a feature of the Hiv...
# 12927  There are a lot of methods in HCatalog that ha...
# 12928  Introduced in HIVE-13068.\n\n{{(case when key<...
# 12929  Most of the vectorization related q-tests oper...
# 12930  hive.warehouse.subdir.inherit.perms doesn't wo...
# 12931                                                NaN
# 12932  hive-schema-0.13.0.postgres.sql doesn't work. ...
# 12933  Compiler should capture the transform URI as i...
# 12934  Doing an "alter table foo drop partition ('bar...
# 12935  There was a performance concern earlier, but H...
# 12936  If {{--incremental}} is specified in Beeline, ...
# 12937  BaseCharUtils checks whether the length of a c...
# 12938  "as" should be optional in select expression. ...
# 12939                                                NaN
# 12940  I found that the {{humanReadableInt(long numbe...
# 12941                                                NaN
# 12942  {code:java}\r\ncreate table cx2(bool1 boolean)...
# 12943  All of these errorCode values are associated w...
# 12944                                                NaN
# 12945  JDBC standalone contains many shaded jars, whi...
#
#                                         components affects_versions  \
# 0                                    HBase Handler           0.13.0
# 1                                             llap            3.0.0
# 2                                              CBO       cbo-branch
# 3                                              NaN           0.13.0
# 4                                              NaN      2.1.1 2.2.0
# 5                                              NaN           0.14.0
# 6                                Druid integration            3.0.0
# 7                                             JDBC            2.1.0
# 8                             Configuration Web UI            3.0.0
# 9                                              NaN            0.5.0
# 10                                             NaN            4.0.0
# 11                                             NaN           0.14.0
# 12                                   Vectorization            3.0.0
# 13                                    Transactions            4.0.0
# 14                                             NaN            0.8.0
# 15                                             NaN            1.0.0
# 16                                             NaN            0.7.0
# 17                            Encryption Metastore      2.0.1 2.1.0
# 18                                             NaN             llap
# 19                                             NaN            2.0.0
# 20                            Standalone Metastore            3.0.0
# 21                                            llap            2.2.0
# 22                               Druid integration            3.0.0
# 23                                             SQL           0.13.0
# 24                                       Metastore      3.0.0 2.4.0
# 25                               Logical Optimizer            2.1.0
# 26                           CBO Logical Optimizer            1.1.0
# 27                                 Query Processor           0.10.0
# 28                                           Spark            1.1.0
# 29                                     HiveServer2            3.0.0
# ...                                            ...              ...
# 12916                                Documentation            0.3.0
# 12917                                  HiveServer2            4.0.0
# 12918                                 File Formats           0.13.0
# 12919                    Serializers/Deserializers            4.0.0
# 12920                                          NaN            4.0.0
# 12921                                        Spark            1.1.0
# 12922                                      Logging            2.1.0
# 12923                                          NaN           0.13.0
# 12924                                          NaN            3.1.0
# 12925  Query Planning Query Processor Transactions            2.3.0
# 12926                                       Web UI            4.0.0
# 12927                                     HCatalog           0.14.0
# 12928                                          CBO            2.1.0
# 12929                                          NaN            3.0.0
# 12930                       Authorization Security           0.14.0
# 12931                                          NaN            2.2.0
# 12932                                          NaN           0.12.0
# 12933                                   Parser SQL            1.1.0
# 12934                                      Locking           0.14.0
# 12935                                   Statistics            2.3.0
# 12936                                      Beeline            2.3.0
# 12937                                          CBO            2.0.0
# 12938                              Query Processor            0.4.0
# 12939                                          NaN           0.13.0
# 12940                                          API            4.0.0
# 12941                                          NaN           0.12.0
# 12942                                          NaN            4.0.0
# 12943                                          NaN           0.12.0
# 12944                                          NaN            2.2.0
# 12945                                         JDBC      2.0.1 2.1.0
#
#                                                 comments  label
# 0      navis requested code review of "HIVE-3617 [jir...      1
# 1      Initial patch, restructured the LlapTaskUmbili...      1
# 2      [~ashutoshc], could you take a look? Thanks\n+...      1
# 3      +1 LGTM\nreuploading for jenkins\nin trunk and...      1
# 4      The bug is introduced by support of variable s...      1
# 5      RB: https://reviews.apache.org/r/24081/\nParse...      1
# 6      +cc [~bslim] [~jcamachorodriguez] small change...      1
# 7      Attaching patch with fix and test. Also moved ...      1
# 8      Changed WebUI / Drilldown / Query Plan so that...      1
# 9      array and map are simpler - we can work on tha...      1
# 10     [https://reviews.apache.org/r/68178/]\r\n\r\n ...      1
# 11     Addressing review comments.\nFixing TestHiveMe...      1
# 12     llap_smb & row_id failure is unrelated, later ...      1
# 13     Disabling vectorization fixes the issue.\nDisa...      1
# 14     \n--------------------------------------------...      1
# 15     +1 LGTM. +1 for 0.14 as well.\nCommitted to tr...      1
# 16     Actually the _tmp files are taken care of by F...      1
# 17     Patch has been uploaded to https://reviews.apa...      1
# 18     {code}\n+    if("llap".equals(HiveConf.getVar(...      1
# 19     Patch on top of HIVE-11676\nRebased the patche...      1
# 20     Committed to standalone-metastore branch.\nCC:...      1
# 21     timelineServerUri could be checked earlier too...      1
# 22     Can you please also create a RB for this?\nhtt...      1
# 23     Work in progress.  This patch depends on HIVE-...      1
# 24     Notification Events (MNNotificationLog, Notifi...      1
# 25     Problem is in PPD and it only happens for mult...      1
# 26     Too many failures, lets try with one rule a ti...      1
# 27     https://cwiki.apache.org/confluence/display/Hi...      1
# 28     cc: [~vanzin]\nThe patch looks good to me. [~c...      1
# 29     Depends on whether we want to mange functions ...      1
# ...                                                  ...    ...
# 12916  Actually, you might as well start using the ne...      0
# 12917                                                 +1      0
# 12918  Attach HIVE-5728-1.patch. Summary of changes:\...      0
# 12919  This includes [~jdere]'s patch for sys.logs ta...      0
# 12920               +1\nPushed to master. Thanks, Denys!      0
# 12921  I ran explain on the two queries and noticed s...      0
# 12922  [~sershe] Could you review this patch? Small c...      0
# 12923  CC'ing [~thejas] and [~ashutoshc] as they work...      0
# 12924  +1\nPushed to master and branch-3. Thanks, Sli...      0
# 12925  OK, was looking at the wrong version\nSomeone ...      0
# 12926  [~xuefuz] Thanks very much for the suggestion ...      0
# 12927  +1 on the idea.  we'll also be able to remove ...      0
# 12928  [~ashutoshc], could you take a look? I went th...      0
# 12929  Initial patch. More test cases to add.\nHi [~v...      0
# 12930  Please review attached patch. With this, the n...      0
# 12931  The patch. Will test on a cluster shortly.\nSe...      0
# 12932  I've attached a patch for this issue.\ncc: [~p...      0
# 12933  +1 pending tests\n[~prasadm] do you want to up...      0
# 12934  This patch depends on HIVE-7202.\nForgot to wa...      0
# 12935  Expecting updates in golden files.\nCurrently ...      0
# 12936  [~stakiar] I am pretty new to Hive, so correct...      0
# 12937  rebase and resubmit the patch\n[~jcamachorodri...      0
# 12938  looks good. will commit if tests pass.\nthere ...      0
# 12939  Small (logically) patch\n+1\n[~ehans] can you ...      0
# 12940  I don't see this method is used anywhere in Hi...      0
# 12941  Deleted metastore/src/java/org/apache/hadoop/h...      0
# 12942  For Sel we need to return NULL in such cases. ...      0
# 12943  navis requested code review of "HIVE-4593 [jir...      0
# 12944  For now, just fail better (and later) - long c...      0
# 12945  [~vgumashta]: I have attached a patch which do...      0
#
# [12946 rows x 15 columns]

# %%
df.drop(['summary', 'description', 'comments'], axis=1, inplace=True)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
numeric_features = ['num_of_insertions', 'num_of_deletions', 'num_of_changed_files', 
                      'day_of_week', 'hour_of_commit', 'solve_time', 'resolution_time', 
                     'solve_res_diff', 'number_of_comments']

numeric_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))])

# categorical encoding: http://contrib.scikit-learn.org/categorical-encoding/

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features)],
    remainder='drop')

processed_features = numeric_features

# %%
X = df.drop('label', axis=1)
y = df['label']
# preprocess X
X = preprocessor.fit_transform(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier(n_estimators=200)
model.fit(X_train, y_train)
print("model score: %.3f" % model.score(X_test, y_test))
# Out:
# model score: 0.700

# %%
def get_feature_importances(model):
    fetaure_importances = zip(processed_features, model.feature_importances_)
    fetaure_importances = sorted(fetaure_importances, key=lambda x: x[1], reverse=True)
    for feature_name, importance in fetaure_importances:
        print("%s: %f" % (feature_name, importance))

# %%
get_feature_importances(model)
# Out:
# num_of_insertions: 0.200795
# solve_res_diff: 0.128454
# num_of_deletions: 0.118902
# solve_time: 0.115189
# resolution_time: 0.113836
# num_of_changed_files: 0.101661
# number_of_comments: 0.089577
# hour_of_commit: 0.080276
# day_of_week: 0.051311
